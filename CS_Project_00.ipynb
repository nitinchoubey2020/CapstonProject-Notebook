# %%
# import necessary Libraries
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.22.0               |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.22.0-pyh9f0ad1d_0
#
#
#
# ...
# geopy-1.22.0         | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# ...

# %%
# Define Foursquare Credentials and Versions
CLIENT_ID = 'RO4LIOP5MMIONX2KITRQ3QEBS2FZYWW13MAGJRJZL0T3PBVK' # your Foursquare ID
CLIENT_SECRET = '5XKOATUE1FBD0QP5UHXJSSAZFRBZ1LCCYLH1Z1PQW0C1KMTE' # your Foursquare Secret

VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: RO4LIOP5MMIONX2KITRQ3QEBS2FZYWW13MAGJRJZL0T3PBVK
# CLIENT_SECRET:5XKOATUE1FBD0QP5UHXJSSAZFRBZ1LCCYLH1Z1PQW0C1KMTE

# %%
address = 'Lemon Tree Hotel, Pune'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 18.585510999999997 73.73423639280874

# %%
# Search Nearby Restaurants withn 2 km range
search_query = 'restaurant'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# restaurant .... OK!

# %%
#Get Data from FourSquare app
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=RO4LIOP5MMIONX2KITRQ3QEBS2FZYWW13MAGJRJZL0T3PBVK&client_secret=5XKOATUE1FBD0QP5UHXJSSAZFRBZ1LCCYLH1Z1PQW0C1KMTE&ll=18.585510999999997,73.73423639280874&v=20180604&query=restaurant&radius=1000&limit=30'

# %%
# Get the results
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ec12920df2774001b69176f'},
#  'response': {'venues': [{'id': '51115c1be4b099b0ac019f6e',
#     'name': 'Irish restaurant',
#     'location': {'lat': 18.584074020385742,
#      'lng': 73.72972106933594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 18.584074020385742,
#        'lng': 73.72972106933594}],
#      'distance': 502,
#      'cc': 'IN',
#      'country': 'India',
#      'formattedAddress': ['India']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1589717081',
#     'hasPerk': False},
#    {'id': '54afe96d498ed92cfa409ac7',
#     'name': 'Cascade Restaurant - Le Royal',
#     'location': {'address': 'Le Royal',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
#dataframe.head(10)
dataframe
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                           name  \
# 0  51115c1be4b099b0ac019f6e               Irish restaurant
# 1  54afe96d498ed92cfa409ac7  Cascade Restaurant - Le Royal
# 2  50544656e4b0e5434c68d557              Rishan Restaurant
# 3  57514a5d498e66ad771e8903                  It Restaurant
# 4  52414d5811d265274c3e70ea                  Hotel Mahadev
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1589717081    False
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1589717081    False
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1589717081    False
# 3  [{'id': '54135bf5e4b08f3d2429dfdd', 'name': 'N...  v-1589717081    False
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                             name               categories        lat  \
# 0               Irish restaurant        Indian Restaurant  18.584074
# 1  Cascade Restaurant - Le Royal        Indian Restaurant  18.584033
# 2              Rishan Restaurant        Indian Restaurant  18.594943
# 3                  It Restaurant  North Indian Restaurant  18.591648
# 4                  Hotel Mahadev        Indian Restaurant  18.579500
#
#          lng                                     labeledLatLngs  distance  cc  \
# 0  73.729721  [{'label': 'display', 'lat': 18.58407402038574...       502  IN
# 1  73.729705  [{'label': 'display', 'lat': 18.58403253413918...       505  IN
# 2  73.734934  [{'label': 'display', 'lat': 18.594943, 'lng':...      1052  IN
# 3  73.741030  [{'label': 'display', 'lat': 18.591648, 'lng':...       990  IN
# 4  73.736997  [{'label': 'display', 'lat': 18.57949962479913...       729  IN
#
#   country                                   formattedAddress  \
# ...

# %%
dataframe_filtered.name
# Out:
# 0                 Irish restaurant
# 1    Cascade Restaurant - Le Royal
# 2                Rishan Restaurant
# 3                    It Restaurant
# 4                    Hotel Mahadev
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup = 'Lemon Tree Hotel, Pune',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# ID of Lamon Tree Restaurant
venue_id = '4bb8aee51261d13a0bcee898'
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4bb8aee51261d13a0bcee898?client_id=RO4LIOP5MMIONX2KITRQ3QEBS2FZYWW13MAGJRJZL0T3PBVK&client_secret=5XKOATUE1FBD0QP5UHXJSSAZFRBZ1LCCYLH1Z1PQW0C1KMTE&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'description', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto'])
# {'id': '4bb8aee51261d13a0bcee898',
#  'name': 'Lemon Tree Hotel',
#  'contact': {'phone': '+912044232323', 'formattedPhone': '+91 20 4423 2323'},
#  'location': {'address': 'P4, Rajiv Gandhi Infotech Park, Phase 1',
#   'crossStreet': 'Hinjewadi',
#   'lat': 18.585771417876245,
#   'lng': 73.73427830550241,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 18.585771417876245,
#     'lng': 73.73427830550241}],
#   'postalCode': '411057',
#   'cc': 'IN',
#   'city': 'Pune',
#   'state': 'Mahārāshtra',
#   'country': 'India',
# ...

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.0

# %%
venue_id = '51115c1be4b099b0ac019f6e' # ID of irish restaurant = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '54afe96d498ed92cfa409ac7' # ID of Cascade Restaurant - Le Royal restaurant = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
# Exploring the Location
latitude = 18.585771417876245
longitude = 73.73427830550241
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=RO4LIOP5MMIONX2KITRQ3QEBS2FZYWW13MAGJRJZL0T3PBVK&client_secret=5XKOATUE1FBD0QP5UHXJSSAZFRBZ1LCCYLH1Z1PQW0C1KMTE&ll=18.585771417876245,73.73427830550241&v=20180604&radius=1000&limit=30'

# %%
import requests
results = requests.get(url).json()
'There are {} around Ecco restaurant.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 22 around Ecco restaurant.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4ffe56b9e4b07fd059960667',
#   'name': 'Accenture Services Pvt. Ltd.',
#   'location': {'address': 'It-1, It-4 & It-7 Building, Qubix Business Parks, SNo154/6 Rajiv Gandhi Infotech park, Phase 1, Hinjewadi',
#    'crossStreet': 'Hinjewadi',
#    'lat': 18.580927,
#    'lng': 73.736885,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 18.580927,
#      'lng': 73.736885}],
#    'distance': 605,
#    'postalCode': '411057',
#    'cc': 'IN',
#    'city': 'Pune',
#    'state': 'Mahārāshtra',
#    'country': 'India',
#    'formattedAddress': ['It-1, It-4 & It-7 Building, Qubix Business Parks, SNo154/6 Rajiv Gandhi Infotech park, Phase 1, Hinjewadi (Hinjewadi)',
#     'Pune 411057',
#     'Mahārāshtra',
#     'India']},
#   'categories': [{'id': '52f2ab2ebcbc57f1066b8b36',
#     'name': 'IT Services',
# ...

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(28)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                              name                     categories  \
# 0   Accenture Services Pvt. Ltd.   IT Services
# 1   Lemon Tree Hotel               Hotel
# 2   Tamanna Executive              Motel
# 3   Chai Tapri - I2IT / Symbiosis  Snack Place
# 4   Mezza 9                        Mexican Restaurant
# 5   SUBWAY                         Sandwich Place
# 6   Citrus Cafe                    Café
# 7   RushHrs                        Fast Food Restaurant
# 8   Hyatt Place Pune/Hinjawadi     Hotel
# 9   Hyatt Place                    Hotel
# 10  Kalyan Bhel                    Chaat Place
# 11  Eatsome                        Fast Food Restaurant
# 12  Faaso's                        Fast Food Restaurant
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)
    # display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'
